# %%
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# fatal: destination path 'pulse' already exists and is not an empty directory.

# %%
import os
path = r"C:/Users/Hari Prashad K/pulse/data/aggregated/transaction/country/india/state/"

#path"C:\Users\Hari Prashad K/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
# Agg_state_list

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path = r"C:/Users/Hari Prashad K/pulse/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transaction_type'].append(Name)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i.title())
              clm['Year'].append(int(j))
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Trans=pd.DataFrame(clm)
Agg_Trans
# Out:
#                           State  Year  Quater          Transaction_type  \
# 0     Andaman-&-Nicobar-Islands  2018       1  Recharge & bill payments
# 1     Andaman-&-Nicobar-Islands  2018       1     Peer-to-peer payments
# 2     Andaman-&-Nicobar-Islands  2018       1         Merchant payments
# 3     Andaman-&-Nicobar-Islands  2018       1        Financial Services
# 4     Andaman-&-Nicobar-Islands  2018       1                    Others
# ...                         ...   ...     ...                       ...
# 5029                West-Bengal  2024       4         Merchant payments
# 5030                West-Bengal  2024       4     Peer-to-peer payments
# 5031                West-Bengal  2024       4  Recharge & bill payments
# 5032                West-Bengal  2024       4        Financial Services
# 5033                West-Bengal  2024       4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# ...

# %%
import pandas as pd
import json
import os

# Set path to the aggregated user data
path = r"C:/Users/Hari Prashad K/pulse/data/aggregated/user/country/india/state/"
Agg_state_list = os.listdir(path)

# Initialize dataframe columns
clm = {'State': [], 'Year': [], 'Quater': [],'User_brand': [], 'User_count': [], 'User_percentage': [],'registeredUsers': [], 'appOpens': []}

# Extract the data
for i in Agg_state_list:
    p_i = path + i + "/"
    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = p_i + j + "/"
        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            p_k = p_j + k
            with open(p_k, 'r') as Data:
                D = json.load(Data)
                try:
                    registeredUsers = D['data']['aggregated']['registeredUsers']
                    appOpens = D['data']['aggregated']['appOpens']
                    for z in D['data']['usersByDevice']:
                        brand = z['brand']
                        count = z['count']
                        percentage = z['percentage']

                        clm['User_brand'].append(brand)
                        clm['User_count'].append(count)
                        clm['User_percentage'].append(percentage)
                        clm['registeredUsers'].append(registeredUsers)
                        clm['appOpens'].append(appOpens)
                        clm['State'].append(i.title())
                        clm['Year'].append(int(j))
                        clm['Quater'].append(int(k.strip('.json')))
                except:
                    pass

# Create dataframe
Agg_User = pd.DataFrame(clm)
Agg_User
# Out:
#                           State  Year  Quater User_brand  User_count  \
# 0     Andaman-&-Nicobar-Islands  2018       1     Xiaomi        1665
# 1     Andaman-&-Nicobar-Islands  2018       1    Samsung        1445
# 2     Andaman-&-Nicobar-Islands  2018       1       Vivo         982
# 3     Andaman-&-Nicobar-Islands  2018       1       Oppo         501
# 4     Andaman-&-Nicobar-Islands  2018       1    OnePlus         332
# ...                         ...   ...     ...        ...         ...
# 6727                West-Bengal  2022       1     Lenovo      330017
# 6728                West-Bengal  2022       1    Infinix      284678
# 6729                West-Bengal  2022       1       Asus      280347
# 6730                West-Bengal  2022       1      Apple      277752
# 6731                West-Bengal  2022       1     Others     2196334
#
#       User_percentage  registeredUsers   appOpens
# 0            0.247033             6740          0
# ...

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path = r"C:/Users/Hari Prashad K/pulse/data/aggregated/insurance/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[], 'Transaction_type':[], 'Insurance_Transaction_count':[], 'Insurance_Transaction_amount':[]}


for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name= z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transaction_type'].append(Name)
              clm['Insurance_Transaction_count'].append(count)
              clm['Insurance_Transaction_amount'].append(amount)
              clm['State'].append(i.title())
              clm['Year'].append(int(j))
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Insu=pd.DataFrame(clm)
Agg_Insu
# Out:
#                          State  Year  Quater Transaction_type  \
# 0    Andaman-&-Nicobar-Islands  2020       2        Insurance
# 1    Andaman-&-Nicobar-Islands  2020       3        Insurance
# 2    Andaman-&-Nicobar-Islands  2020       4        Insurance
# 3    Andaman-&-Nicobar-Islands  2021       1        Insurance
# 4    Andaman-&-Nicobar-Islands  2021       2        Insurance
# ..                         ...   ...     ...              ...
# 677                West-Bengal  2023       4        Insurance
# 678                West-Bengal  2024       1        Insurance
# 679                West-Bengal  2024       2        Insurance
# 680                West-Bengal  2024       3        Insurance
# 681                West-Bengal  2024       4        Insurance
#
#      Insurance_Transaction_count  Insurance_Transaction_amount
# 0                              6                        1360.0
# 1                             41                       15380.0
# ...

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path = r"C:/Users/Hari Prashad K/pulse/data/map/transaction/hover/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[], 'Place':[], 'Transacion_count':[], 'Transacion_amount':[]}


for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name= z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Place'].append(Name.title())
              clm['Transacion_count'].append(count)
              clm['Transacion_amount'].append(amount)
              clm['State'].append(i.title())
              clm['Year'].append(int(j))
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Trans=pd.DataFrame(clm)
Map_Trans
# Out:
#                            State  Year  Quater  \
# 0      Andaman-&-Nicobar-Islands  2018       1
# 1      Andaman-&-Nicobar-Islands  2018       1
# 2      Andaman-&-Nicobar-Islands  2018       1
# 3      Andaman-&-Nicobar-Islands  2018       2
# 4      Andaman-&-Nicobar-Islands  2018       2
# ...                          ...   ...     ...
# 20599                West-Bengal  2024       4
# 20600                West-Bengal  2024       4
# 20601                West-Bengal  2024       4
# 20602                West-Bengal  2024       4
# 20603                West-Bengal  2024       4
#
#                                    Place  Transacion_count  Transacion_amount
# 0      North And Middle Andaman District               442       9.316631e+05
# 1                 South Andaman District              5688       1.256025e+07
# 2                      Nicobars District               528       1.139849e+06
# 3      North And Middle Andaman District               825       1.317863e+06
# ...

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path = r"C:/Users/Hari Prashad K/pulse/data/map/user/hover/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[], 'district':[],'registeredUsers': [], 'appOpens':[]}


for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for K in D["data"]["hoverData"].items() :
              district = K[0]
              registeredUsers = K[1]["registeredUsers"]
              appOpens = K[1]["appOpens"]
              clm['district'].append(district.title())
              clm['registeredUsers'].append(registeredUsers)
              clm['appOpens'].append(appOpens)
              clm['State'].append(i.title())
              clm['Year'].append(int(j))
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_User=pd.DataFrame(clm)
Map_User
# Out:
#                            State  Year  Quater  \
# 0      Andaman-&-Nicobar-Islands  2018       1
# 1      Andaman-&-Nicobar-Islands  2018       1
# 2      Andaman-&-Nicobar-Islands  2018       1
# 3      Andaman-&-Nicobar-Islands  2018       2
# 4      Andaman-&-Nicobar-Islands  2018       2
# ...                          ...   ...     ...
# 20603                West-Bengal  2024       4
# 20604                West-Bengal  2024       4
# 20605                West-Bengal  2024       4
# 20606                West-Bengal  2024       4
# 20607                West-Bengal  2024       4
#
#                                 district  registeredUsers   appOpens
# 0      North And Middle Andaman District              632          0
# 1                 South Andaman District             5846          0
# 2                      Nicobars District              262          0
# 3      North And Middle Andaman District              911          0
# ...

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path = r"C:/Users/Hari Prashad K/pulse/data/map/insurance/hover/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[], 'Place':[], 'Insurance_Transacion_count':[], 'Insurance_Transacion_amount':[]}


for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name= z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Place'].append(Name.title())
              clm['Insurance_Transacion_count'].append(count)
              clm['Insurance_Transacion_amount'].append(amount)
              clm['State'].append(i.title())
              clm['Year'].append(int(j))
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Insu=pd.DataFrame(clm)
Map_Insu
# Out:
#                            State  Year  Quater  \
# 0      Andaman-&-Nicobar-Islands  2020       2
# 1      Andaman-&-Nicobar-Islands  2020       2
# 2      Andaman-&-Nicobar-Islands  2020       3
# 3      Andaman-&-Nicobar-Islands  2020       3
# 4      Andaman-&-Nicobar-Islands  2020       3
# ...                          ...   ...     ...
# 13871                West-Bengal  2024       4
# 13872                West-Bengal  2024       4
# 13873                West-Bengal  2024       4
# 13874                West-Bengal  2024       4
# 13875                West-Bengal  2024       4
#
#                                    Place  Insurance_Transacion_count  \
# 0                 South Andaman District                           3
# 1                      Nicobars District                           3
# 2      North And Middle Andaman District                           1
# 3                 South Andaman District                          35
# ...

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path = r"C:/Users/Hari Prashad K/pulse/data/top/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={ 'State':[],'Year':[],'Quater':[], 'district_name':[], 'districct_Transacion_count':[], 'district_Transacion_amount':[]}


for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['districts']:
                  Name= z['entityName']
                  count=z['metric']['count']
                  amount=z['metric']['amount']  
                  clm['district_name'].append(Name.title())
                  clm['districct_Transacion_count'].append(count)
                  clm['district_Transacion_amount'].append(amount)
                  clm['State'].append(i.title())
                  clm['Year'].append(int(j))
                  clm['Quater'].append(int(k.strip('.json')))
       
#Succesfully created a dataframe
Top_tans_district=pd.DataFrame(clm)
Top_tans_district
# Out:
#                           State  Year  Quater             district_name  \
# 0     Andaman-&-Nicobar-Islands  2018       1             South Andaman
# 1     Andaman-&-Nicobar-Islands  2018       1                  Nicobars
# 2     Andaman-&-Nicobar-Islands  2018       1  North And Middle Andaman
# 3     Andaman-&-Nicobar-Islands  2018       2             South Andaman
# 4     Andaman-&-Nicobar-Islands  2018       2                  Nicobars
# ...                         ...   ...     ...                       ...
# 8291                West-Bengal  2024       4                    Howrah
# 8292                West-Bengal  2024       4                     Nadia
# 8293                West-Bengal  2024       4                     Malda
# 8294                West-Bengal  2024       4                   Hooghly
# 8295                West-Bengal  2024       4         Paschim Medinipur
#
#       districct_Transacion_count  district_Transacion_amount
# ...

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path = r"C:/Users/Hari Prashad K/pulse/data/top/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={ 'State':[],'Year':[],'Quater':[], 'postal_name':[], 'postal_Transacion_count':[], 'postal_Transacion_amount':[]}


for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['pincodes']:
                  Name= z['entityName']
                  count=z['metric']['count']
                  amount=z['metric']['amount']  
                  clm['postal_name'].append(Name)
                  clm['postal_Transacion_count'].append(count)
                  clm['postal_Transacion_amount'].append(amount)
                  clm['State'].append(i.title())
                  clm['Year'].append(int(j))
                  clm['Quater'].append(int(k.strip('.json')))
       
#Succesfully created a dataframe
Top_trans_postal=pd.DataFrame(clm)
Top_trans_postal
# Out:
#                           State  Year  Quater postal_name  \
# 0     Andaman-&-Nicobar-Islands  2018       1      744101
# 1     Andaman-&-Nicobar-Islands  2018       1      744103
# 2     Andaman-&-Nicobar-Islands  2018       1      744102
# 3     Andaman-&-Nicobar-Islands  2018       1      744105
# 4     Andaman-&-Nicobar-Islands  2018       1      744104
# ...                         ...   ...     ...         ...
# 9994                West-Bengal  2024       4      711101
# 9995                West-Bengal  2024       4      700059
# 9996                West-Bengal  2024       4      700039
# 9997                West-Bengal  2024       4      734001
# 9998                West-Bengal  2024       4      733134
#
#       postal_Transacion_count  postal_Transacion_amount
# 0                        1622              2.769298e+06
# 1                        1223              2.238042e+06
# 2                         969              3.519060e+06
# ...

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path = r"C:/Users/Hari Prashad K/pulse/data/top/user/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={ 'State':[],'Year':[],'Quater':[], 'district_name':[], 'registeredUsers':[]}


for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['districts']:
                Name = z['name']
                count = z['registeredUsers']
                clm['district_name'].append(Name.title())
                clm['registeredUsers'].append(count)
                clm['State'].append(i.title())
                clm['Year'].append(int(j))
                clm['Quater'].append(int(k.strip('.json')))
       
#Succesfully created a dataframe
Top_district_user=pd.DataFrame(clm)
Top_district_user
# Out:
#                           State  Year  Quater             district_name  \
# 0     Andaman-&-Nicobar-Islands  2018       1             South Andaman
# 1     Andaman-&-Nicobar-Islands  2018       1  North And Middle Andaman
# 2     Andaman-&-Nicobar-Islands  2018       1                  Nicobars
# 3     Andaman-&-Nicobar-Islands  2018       2             South Andaman
# 4     Andaman-&-Nicobar-Islands  2018       2  North And Middle Andaman
# ...                         ...   ...     ...                       ...
# 8291                West-Bengal  2024       4                   Hooghly
# 8292                West-Bengal  2024       4                     Nadia
# 8293                West-Bengal  2024       4           Purba Medinipur
# 8294                West-Bengal  2024       4         Paschim Medinipur
# 8295                West-Bengal  2024       4         Paschim Bardhaman
#
#       registeredUsers
# 0                5846
# 1                 632
# 2                 262
# ...

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path = r"C:/Users/Hari Prashad K/pulse/data/top/user/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={ 'State':[],'Year':[],'Quater':[], 'postal_name':[], 'registeredUsers':[]}


for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['pincodes']:
                Name = z['name']
                count = z['registeredUsers']
                clm['postal_name'].append(Name)
                clm['registeredUsers'].append(count)
                clm['State'].append(i.title())
                clm['Year'].append(int(j))
                clm['Quater'].append(int(k.strip('.json')))
       
#Succesfully created a dataframe
Top_postal_user=pd.DataFrame(clm)
Top_postal_user
# Out:
#                           State  Year  Quater postal_name  registeredUsers
# 0     Andaman-&-Nicobar-Islands  2018       1      744103             1608
# 1     Andaman-&-Nicobar-Islands  2018       1      744101             1108
# 2     Andaman-&-Nicobar-Islands  2018       1      744105             1075
# 3     Andaman-&-Nicobar-Islands  2018       1      744102             1006
# 4     Andaman-&-Nicobar-Islands  2018       1      744104              272
# ...                         ...   ...     ...         ...              ...
# 9995                West-Bengal  2024       4      733134           169596
# 9996                West-Bengal  2024       4      700059           169448
# 9997                West-Bengal  2024       4      711302           146034
# 9998                West-Bengal  2024       4      700150           142151
# 9999                West-Bengal  2024       4      711106           142077
#
# [10000 rows x 5 columns]

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path = r"C:/Users/Hari Prashad K/pulse/data/top/insurance/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={ 'State':[],'Year':[],'Quater':[], 'district_name':[], 'Insurance_count':[], 'Insurance_amount': []}


for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['districts']:
                Name = z['entityName']
                count = z['metric']['count']
                amount = z ['metric']['amount']
                clm['district_name'].append(Name.title())
                clm['Insurance_count'].append(count)
                clm['Insurance_amount'].append(amount)
                clm['State'].append(i.title())
                clm['Year'].append(int(j))
                clm['Quater'].append(int(k.strip('.json')))
       
#Succesfully created a dataframe
Top_district_insu=pd.DataFrame(clm)
Top_district_insu
# Out:
#                           State  Year  Quater             district_name  \
# 0     Andaman-&-Nicobar-Islands  2020       2                  Nicobars
# 1     Andaman-&-Nicobar-Islands  2020       2             South Andaman
# 2     Andaman-&-Nicobar-Islands  2020       3             South Andaman
# 3     Andaman-&-Nicobar-Islands  2020       3                  Nicobars
# 4     Andaman-&-Nicobar-Islands  2020       3  North And Middle Andaman
# ...                         ...   ...     ...                       ...
# 5603                West-Bengal  2024       4         Paschim Bardhaman
# 5604                West-Bengal  2024       4         Paschim Medinipur
# 5605                West-Bengal  2024       4                     Malda
# 5606                West-Bengal  2024       4                     Nadia
# 5607                West-Bengal  2024       4           Purba Bardhaman
#
#       Insurance_count  Insurance_amount
# 0                   3             565.0
# ...

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path = r"C:/Users/Hari Prashad K/pulse/data/top/insurance/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={ 'State':[],'Year':[],'Quater':[], 'postal_name':[], 'Insurance_count':[], 'Insurance_amount': []}


for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['pincodes']:
                Name = z['entityName']
                count = z['metric']['count']
                amount = z ['metric']['amount']
                clm['postal_name'].append(Name)
                clm['Insurance_count'].append(count)
                clm['Insurance_amount'].append(amount)
                clm['State'].append(i.title())
                clm['Year'].append(int(j))
                clm['Quater'].append(int(k.strip('.json')))
       
#Succesfully created a dataframe
Top_postal_insu=pd.DataFrame(clm)
Top_postal_insu
# Out:
#                           State  Year  Quater postal_name  Insurance_count  \
# 0     Andaman-&-Nicobar-Islands  2020       2      744301                3
# 1     Andaman-&-Nicobar-Islands  2020       2      744104                2
# 2     Andaman-&-Nicobar-Islands  2020       2      744101                1
# 3     Andaman-&-Nicobar-Islands  2020       3      744112                9
# 4     Andaman-&-Nicobar-Islands  2020       3      744105                7
# ...                         ...   ...     ...         ...              ...
# 6663                West-Bengal  2024       4      711101              713
# 6664                West-Bengal  2024       4      700091              642
# 6665                West-Bengal  2024       4      700150              627
# 6666                West-Bengal  2024       4      700039              619
# 6667                West-Bengal  2024       4      700156              574
#
#       Insurance_amount
# 0                565.0
# ...

# %%
def file_check(a,b,c,d,e,f,g,h,i,j,k,l):
    for df in (a,b,c,d,e,f,g,h,i,j,k,l):
        Null_values=df.isnull().mean()*100
        Datatypes=df.info()
        Duplicate=df.duplicated().sum()
        print(Null_values)
        print(Datatypes)
        print(Duplicate)
        print("***********************************************************************************************************************************")

# %%
file_check(Agg_Trans,
Agg_User,
Agg_Insu,
Map_Trans,
Map_User,
Map_Insu,
Top_tans_district,
Top_trans_postal,
Top_district_user,
Top_postal_user,
Top_district_insu,
Top_postal_insu,)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5034 entries, 0 to 5033
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              5034 non-null   object
#  1   Year               5034 non-null   int64
#  2   Quater             5034 non-null   int64
#  3   Transacion_type    5034 non-null   object
#  4   Transacion_count   5034 non-null   int64
#  5   Transacion_amount  5034 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 236.1+ KB
# State                0.0
# Year                 0.0
# Quater               0.0
# Transacion_type      0.0
# Transacion_count     0.0
# Transacion_amount    0.0
# dtype: float64
# None
# 0
# ***********************************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6732 entries, 0 to 6731
# ...

# %%
Top_postal_insu[Top_postal_insu["postal_name"].isnull()]
# Out:
#        State  Year  Quater postal_name  Insurance_count  Insurance_amount
# 3199  Ladakh  2020       3        None                1             281.0
# 3207  Ladakh  2020       4        None                1             658.0
# 3284  Ladakh  2022       4        None                8           16020.0

# %%
Top_postal_insu.dropna(inplace = True)
Top_postal_insu.shape
# Out:
# (6665, 6)

# %%
# install pymysql package
! pip install pymysql
import pymysql as db

# %%
user="phonepay"
passcode="PhonePay@14"
host_name="localhost"
db_name="pp"

# %%
import pymysql as db
db_connection = db.connect(
                user=user,
                database=db_name,
                password=passcode,
                host=host_name)

# %%
my_cursor=db_connection.cursor()

# %%
Agg_Trans_table="""CREATE TABLE Agg_Trans (
                State varchar(45),
                Year int,
                Quater int,
                Transacion_type varchar(40),
                Transacion_count bigint,
                Transacion_amount float)"""
my_cursor.execute(Agg_Trans_table)

insert_Agg_Trans_rows= """INSERT INTO Agg_Trans VALUES (%s,%s,%s,%s,%s,%s)"""

for rows in Agg_Trans.values:
    my_cursor.execute(insert_Agg_Trans_rows,tuple(rows))

db_connection.commit()

# %%
Agg_User_table="""CREATE TABLE Agg_User (
                State varchar(45),
                Year int,
                Quater int,
                User_brand varchar(20),
                User_count int,
                User_percentage float,
                registeredUsers bigint,
                appOpens bigint)"""
my_cursor.execute(Agg_User_table)

insert_Agg_User_rows = """INSERT INTO Agg_User VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"""

for rows in Agg_User.values:
    my_cursor.execute(insert_Agg_User_rows,tuple(rows))

db_connection.commit()

# %%
Agg_Insu_table="""CREATE TABLE Agg_Insu (
                    State varchar(45),
                    Year int,
                    Quater int,
                    Transacion_type Varchar(20),
                    Insurance_Transacion_count int,
                    Insurance_Transacion_amount float)"""
my_cursor.execute(Agg_Insu_table)

insert_Agg_Insu_rows = """INSERT INTO Agg_Insu VALUES (%s,%s,%s,%s,%s,%s)"""

for rows in Agg_Insu.values:
    my_cursor.execute(insert_Agg_Insu_rows,tuple(rows))

db_connection.commit()

# %%
Map_Trans_table = """CREATE TABLE Map_Trans (
                    State varchar(45),
                    Year int,
                    Quater int,
                    Place varchar (50),
                    Transacion_count int,
                    Transacion_amount float
                    )"""
my_cursor.execute(Map_Trans_table)

insert_Map_Trans_rows = """INSERT INTO Map_Trans VALUES (%s,%s,%s,%s,%s,%s)"""

for rows in Map_Trans.values:
    my_cursor.execute(insert_Map_Trans_rows,tuple(rows))

db_connection.commit()

# %%
Map_User_table = """CREATE TABLE Map_User (
                    State varchar(45),
                    Year int,
                    Quater int,
                    district varchar(50),
                    registeredUsers int,
                    appOpens int
                    )"""
my_cursor.execute(Map_User_table)

insert_Map_User_rows = """INSERT INTO Map_User VALUES (%s,%s,%s,%s,%s,%s)"""

for rows in Map_User.values:
    my_cursor.execute(insert_Map_User_rows,tuple(rows))

db_connection.commit()

# %%
Map_Insu_table = """CREATE TABLE Map_Insu (
                    State varchar(45),
                    Year int,
                    Quater int,
                    Place varchar(50),
                    Insurance_Transacion_count int,
                    Insurance_Transacion_amount float
                    )"""
my_cursor.execute(Map_Insu_table)

insert_Map_Insu_rows = """INSERT INTO Map_Insu VALUES (%s,%s,%s,%s,%s,%s)"""

for rows in Map_Insu.values:
    my_cursor.execute(insert_Map_Insu_rows,tuple(rows))

db_connection.commit()

# %%
Top_tans_district_table = """CREATE TABLE Top_tans_district (
                    State varchar(45),
                    Year int,
                    Quater int,
                    district_name varchar(50),
                    district_Transacion_count int,
                    district_Transacion_amount float
                    )"""
my_cursor.execute(Top_tans_district_table)

insert_Top_tans_district_table_rows = """INSERT INTO Top_tans_district VALUES (%s,%s,%s,%s,%s,%s)"""

for rows in Top_tans_district.values:
    my_cursor.execute(insert_Top_tans_district_table_rows,tuple(rows))

db_connection.commit()

# %%
Top_trans_postal_table = """CREATE TABLE Top_trans_postal(
                    State varchar(45),
                    Year int,
                    Quater int,
                    postal_name varchar(20),
                    postal_Transacion_count int,
                    postal_Transacion_amount float
                    )"""
my_cursor.execute(Top_trans_postal_table)

insert_Top_trans_postal_table_rows = """INSERT INTO Top_trans_postal VALUES (%s,%s,%s,%s,%s,%s)"""

for rows in Top_trans_postal.values:
    my_cursor.execute(insert_Top_trans_postal_table_rows,tuple(rows))

db_connection.commit()

# %%
Top_district_user_table = """CREATE TABLE Top_district_user(
                    State varchar(45),
                    Year int,
                    Quater int,
                    district_name varchar(50),
                    registeredUsers int
                    )"""
my_cursor.execute(Top_district_user_table)

insert_Top_district_user_rows = """INSERT INTO Top_district_user VALUES (%s,%s,%s,%s,%s)"""

for rows in Top_district_user.values:
    my_cursor.execute(insert_Top_district_user_rows,tuple(rows))

db_connection.commit()

# %%
Top_postal_user_table = """CREATE TABLE Top_postal_user(
                    State varchar(45),
                    Year int,
                    Quater int,
                    postal_name varchar(20),
                    registeredUsers int
                    )"""
my_cursor.execute(Top_postal_user_table)

insert_Top_postal_user_rows = """INSERT INTO Top_postal_user  VALUES (%s,%s,%s,%s,%s)"""

for rows in Top_postal_user.values:
    my_cursor.execute(insert_Top_postal_user_rows,tuple(rows))

db_connection.commit()

# %%
Top_district_insu_table = """CREATE TABLE Top_district_insu(
                    State varchar(45),
                    Year int,
                    Quater int,
                    district_name varchar(50),
                    Insurance_count int,
                    Insurance_amount float
                    )"""
my_cursor.execute(Top_district_insu_table)

insert_Top_district_insu_rows = """INSERT INTO Top_district_insu  VALUES (%s,%s,%s,%s,%s,%s)"""

for rows in Top_district_insu.values:
    my_cursor.execute(insert_Top_district_insu_rows,tuple(rows))

db_connection.commit()

# %%
Top_postal_insu_table = """CREATE TABLE Top_postal_insu(
                    State varchar(45),
                    Year int,
                    Quater int,
                    postal_name varchar(20),
                    Insurance_count int,
                    Insurance_amount float
                    )"""
my_cursor.execute(Top_postal_insu_table)

insert_Top_postal_insu_rows = """INSERT INTO Top_postal_insu  VALUES (%s,%s,%s,%s,%s,%s)"""

for rows in Top_postal_insu.values:
    my_cursor.execute(insert_Top_postal_insu_rows,tuple(rows))

db_connection.commit()

# %%
# 1. Decoding Transaction Dynamics on PhonePe

sql_1="""SELECT 
    State,
    Year,
    Quater,
    Transacion_type,
    SUM(Transacion_Count) AS Total_Transactions,
    SUM(Transacion_Amount) AS Total_Amount
    FROM Agg_Trans
    GROUP BY 
        State, Year, Quater, Transacion_type
    ORDER BY 
        State, Year, Quater"""

my_cursor.execute(sql_1)
Decoding_Transaction=my_cursor.fetchall()
columns=[col[0] for col in my_cursor.description]
Decoding_Transaction=pd.DataFrame(Decoding_Transaction, columns=columns)
Decoding_Transaction
# Out:
#                           State  Year  Quater           Transacion_type  \
# 0     Andaman-&-Nicobar-Islands  2018       1        Financial Services
# 1     Andaman-&-Nicobar-Islands  2018       1         Merchant payments
# 2     Andaman-&-Nicobar-Islands  2018       1                    Others
# 3     Andaman-&-Nicobar-Islands  2018       1     Peer-to-peer payments
# 4     Andaman-&-Nicobar-Islands  2018       1  Recharge & bill payments
# ...                         ...   ...     ...                       ...
# 5029                West-Bengal  2024       4        Financial Services
# 5030                West-Bengal  2024       4         Merchant payments
# 5031                West-Bengal  2024       4                    Others
# 5032                West-Bengal  2024       4     Peer-to-peer payments
# 5033                West-Bengal  2024       4  Recharge & bill payments
#
#      Total_Transactions  Total_Amount
# 0                    33  1.060142e+04
# ...

# %%
# 2. Device Dominance and User Engagement Analysis

sql_2="""SELECT 
    State,
    User_brand,
    Year,
    Quater,
    SUM(registeredUsers) AS Total_Registered_Users,
    SUM(appOpens) AS Total_App_Opens,
    CASE 
        WHEN SUM(registeredUsers) = 0 THEN 0
        ELSE ROUND(SUM(appOpens) * 1.0 / SUM(registeredUsers), 2)
    END AS Engagement_Rate
FROM Agg_User
GROUP BY 
    State, User_brand, Year, Quater
ORDER BY 
    State, Engagement_Rate DESC"""
my_cursor.execute(sql_2)
User_Engagement_Analysis=my_cursor.fetchall()
columns=[col[0] for col in my_cursor.description]
User_Engagement_Analysis= pd.DataFrame(User_Engagement_Analysis,columns=columns)
User_Engagement_Analysis
# Out:
#                           State User_brand  Year  Quater  \
# 0     Andaman-&-Nicobar-Islands    Samsung  2022       1
# 1     Andaman-&-Nicobar-Islands   Motorola  2022       1
# 2     Andaman-&-Nicobar-Islands     Others  2022       1
# 3     Andaman-&-Nicobar-Islands       Vivo  2022       1
# 4     Andaman-&-Nicobar-Islands     Xiaomi  2022       1
# ...                         ...        ...   ...     ...
# 6727                West-Bengal     Huawei  2019       1
# 6728                West-Bengal     Others  2019       1
# 6729                West-Bengal     Huawei  2018       4
# 6730                West-Bengal       Asus  2018       4
# 6731                West-Bengal     Xiaomi  2019       1
#
#      Total_Registered_Users Total_App_Opens Engagement_Rate
# 0                     76288         3847407           50.43
# 1                     76288         3847407           50.43
# 2                     76288         3847407           50.43
# ...

# %%
# 3.Transaction Analysis for Market Expansion

sql_3="""SELECT 
    State,
    Year,
    Quater,
    district_name,
    SUM(district_Transacion_Count) AS Total_Transactions,
    SUM(district_Transacion_Amount) AS Total_Amount
FROM top_tans_district
GROUP BY 
    State, Year, Quater, district_name
ORDER BY 
    State, Year, Quater"""
my_cursor.execute(sql_3)
Transaction_Analysis=my_cursor.fetchall()
columns=[col[0] for col in my_cursor.description]
Transaction_Analysis= pd.DataFrame(Transaction_Analysis,columns=columns)
Transaction_Analysis
# Out:
#                           State  Year  Quater               district_name  \
# 0     Andaman-&-Nicobar-Islands  2018       1                    Nicobars
# 1     Andaman-&-Nicobar-Islands  2018       1    North And Middle Andaman
# 2     Andaman-&-Nicobar-Islands  2018       1               South Andaman
# 3     Andaman-&-Nicobar-Islands  2018       2                    Nicobars
# 4     Andaman-&-Nicobar-Islands  2018       2    North And Middle Andaman
# ...                         ...   ...     ...                         ...
# 8291                West-Bengal  2024       4                       Nadia
# 8292                West-Bengal  2024       4  North Twenty Four Parganas
# 8293                West-Bengal  2024       4           Paschim Medinipur
# 8294                West-Bengal  2024       4             Purba Medinipur
# 8295                West-Bengal  2024       4  South Twenty Four Parganas
#
#      Total_Transactions  Total_Amount
# 0                   528  1.139849e+06
# ...

# %%
# 4.Insurance Transactions Analysis
# State Insurance

sql_4="""SELECT 
    State,
    Year,
    Quater,
    SUM(Insurance_Transacion_count) AS Total_Transacions,
    SUM(Insurance_Transacion_amount) AS Total_Transacion_Amount
FROM Agg_Insu
GROUP BY State,Year,Quater
ORDER BY Total_Transacion_Amount DESC"""

my_cursor.execute(sql_4)
State_Insurance_Analysis=my_cursor.fetchall()
columns=[col[0] for col in my_cursor.description]
State_Insurance_Analysis= pd.DataFrame(State_Insurance_Analysis,columns=columns)
State_Insurance_Analysis
# Out:
#                          State  Year  Quater Total_Transacions  \
# 0                    Karnataka  2024       4            183532
# 1                    Karnataka  2024       3            174990
# 2                  Maharashtra  2024       4            168078
# 3                    Karnataka  2024       1            169357
# 4                    Karnataka  2023       4            156076
# ..                         ...   ...     ...               ...
# 677                Lakshadweep  2021       1                 4
# 678                     Sikkim  2020       2                21
# 679                     Ladakh  2020       2                14
# 680  Andaman-&-Nicobar-Islands  2020       2                 6
# 681                Lakshadweep  2020       3                 4
#
#      Total_Transacion_Amount
# 0                305861792.0
# 1                287393280.0
# 2                266942704.0
# 3                264708704.0
# 4                248056304.0
# ...

# %%
#  District Insurance

sql_5="""SELECT 
    State,
    district_name,
    Year,
    Quater,
    SUM(Insurance_count) AS Total_Transactions,
    SUM(Insurance_amount) AS Total_Transaction_Amount
FROM Top_district_insu
GROUP BY State, district_name,Year,Quater
ORDER BY Total_Transaction_Amount DESC"""

my_cursor.execute(sql_5)
District_Insurance_Analysis=my_cursor.fetchall()
columns=[col[0] for col in my_cursor.description]
District_Insurance_Analysis= pd.DataFrame(District_Insurance_Analysis,columns=columns)
District_Insurance_Analysis
# Out:
#           State       district_name  Year  Quater Total_Transactions  \
# 0     Karnataka     Bengaluru Urban  2024       4              95390
# 1     Karnataka     Bengaluru Urban  2024       3              96935
# 2     Karnataka     Bengaluru Urban  2024       1              90180
# 3     Karnataka     Bengaluru Urban  2023       4              88349
# 4     Karnataka     Bengaluru Urban  2024       2              74985
# ...         ...                 ...   ...     ...                ...
# 5603   Nagaland             Kiphire  2020       4                  1
# 5604   Nagaland               Peren  2021       1                  1
# 5605   Nagaland             Kiphire  2021       1                  1
# 5606  Meghalaya    South Garo Hills  2020       4                  1
# 5607  Meghalaya  West Jaintia Hills  2020       4                  1
#
#       Total_Transaction_Amount
# 0                  159224816.0
# 1                  156230240.0
# 2                  142519456.0
# ...

# %%
# postal Insurance

sql_6="""SELECT 
    State,
    postal_name,
    Year,
    Quater,
    SUM(Insurance_count) AS Total_Transactions,
    SUM(Insurance_amount) AS Total_Transaction_Amount
FROM top_postal_insu
GROUP BY State, postal_name,Year,Quater
ORDER BY Total_Transaction_Amount DESC"""

my_cursor.execute(sql_6)
Postal_Insurance_Analysis=my_cursor.fetchall()
columns=[col[0] for col in my_cursor.description]
Postal_Insurance_Analysis= pd.DataFrame(Postal_Insurance_Analysis,columns=columns)
Postal_Insurance_Analysis
# Out:
#             State postal_name  Year  Quater Total_Transactions  \
# 0       Karnataka      560068  2024       4               3520
# 1       Karnataka      560068  2024       1               3871
# 2       Karnataka      560068  2023       4               3947
# 3       Karnataka      560100  2024       3               3241
# 4       Karnataka      560068  2024       3               3453
# ...           ...         ...   ...     ...                ...
# 6660  Lakshadweep      682556  2021       4                  1
# 6661       Ladakh      194102  2020       4                  1
# 6662  Lakshadweep      682551  2024       1                  1
# 6663  Lakshadweep      682554  2024       1                  1
# 6664  Lakshadweep      682557  2024       2                  1
#
#       Total_Transaction_Amount
# 0                    5740577.0
# 1                    5672343.0
# 2                    5606578.0
# 3                    5455946.0
# 4                    5413163.0
# ...

# %%
#  5. User Registration Analysis
# Top States by Registered Users

sql_7="""SELECT 
    State,
    Year,
    Quater,
    SUM(registeredUsers) AS Total_Registered_Users
FROM Agg_User
GROUP BY State,Year,Quater
ORDER BY Total_Registered_Users DESC"""

my_cursor.execute(sql_7)
Top_state_User=my_cursor.fetchall()
columns=[col[0] for col in my_cursor.description]
Top_state_User= pd.DataFrame(Top_state_User,columns=columns)
Top_state_User
# Out:
#              State  Year  Quater Total_Registered_Users
# 0      Maharashtra  2022       1              530503930
# 1      Maharashtra  2021       4              500307566
# 2      Maharashtra  2021       3              468393387
# 3      Maharashtra  2021       2              436311667
# 4    Uttar-Pradesh  2022       1              428996612
# ..             ...   ...     ...                    ...
# 607    Lakshadweep  2019       1                  15576
# 608    Lakshadweep  2018       4                  12716
# 609    Lakshadweep  2018       3                  10098
# 610    Lakshadweep  2018       2                   7546
# 611    Lakshadweep  2018       1                   5511
#
# [612 rows x 4 columns]

# %%
#   Top Districts by Registered Users

sql_8="""SELECT 
    State,
    district_name,
    Year,
    Quater,
    SUM(registeredUsers) AS Total_Registered_Users
FROM Top_district_user
GROUP BY State, district_name,Year,Quater
ORDER BY Total_Registered_Users DESC"""


my_cursor.execute(sql_8)
Top_district_user=my_cursor.fetchall()
columns=[col[0] for col in my_cursor.description]
Top_district_user= pd.DataFrame(Top_district_user,columns=columns)
Top_district_user
# Out:
#           State     district_name  Year  Quater Total_Registered_Users
# 0     Karnataka   Bengaluru Urban  2024       2               18127475
# 1     Karnataka   Bengaluru Urban  2024       4               18101416
# 2     Karnataka   Bengaluru Urban  2024       3               17566351
# 3     Karnataka   Bengaluru Urban  2024       1               17506580
# 4     Karnataka   Bengaluru Urban  2023       4               16895567
# ...         ...               ...   ...     ...                    ...
# 8291  Meghalaya  North Garo Hills  2018       1                    254
# 8292  Meghalaya   East Garo Hills  2018       1                    236
# 8293    Mizoram             Saiha  2018       1                    231
# 8294   Nagaland             Peren  2018       1                    218
# 8295   Nagaland           Kiphire  2018       1                    168
#
# [8296 rows x 5 columns]

# %%
#  Top Pin Codes by Registered Users

sql_9="""SELECT 
    State,
    postal_name,
    Year,
    Quater,
    SUM(registeredUsers) AS Total_Registered_Users
FROM Top_postal_user
GROUP BY State, postal_name,Year,Quater
ORDER BY Total_Registered_Users DESC"""


my_cursor.execute(sql_9)
Top_postal_user=my_cursor.fetchall()
columns=[col[0] for col in my_cursor.description]
Top_postal_user= pd.DataFrame(Top_postal_user,columns=columns)
Top_postal_user
# Out:
#               State postal_name  Year  Quater Total_Registered_Users
# 0     Uttar-Pradesh      201301  2024       2                1021560
# 1     Uttar-Pradesh      201301  2024       1                 984239
# 2     Uttar-Pradesh      201301  2024       4                 964283
# 3     Uttar-Pradesh      201301  2023       4                 948041
# 4     Uttar-Pradesh      201301  2024       3                 929874
# ...             ...         ...   ...     ...                    ...
# 9995    Lakshadweep      682558  2019       1                      5
# 9996    Lakshadweep      682557  2024       4                      5
# 9997    Lakshadweep      682557  2024       3                      4
# 9998    Lakshadweep      682558  2018       2                      3
# 9999    Lakshadweep      682558  2018       1                      1
#
# [10000 rows x 5 columns]

# %%
db_connection.close()
